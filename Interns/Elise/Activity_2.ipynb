# %% [markdown]
# <a href="https://colab.research.google.com/github/elsiecolme/EscapeEarth/blob/main/Interns/Elise/Activity_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mpl

from google.colab import drive

drive.mount('/content/gdrive', force_remount = True)
# Out:
# Mounted at /content/gdrive

# %%
df1 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df1.csv',header=0,delimiter=',')
df1
# Out:
#            col1     col2
# 0      272.3966  45.8308
# 1      272.3288  45.9244
# 2      272.3307  45.9255
# 3      272.3711  47.2259
# 4      272.5282  47.0887
# ...         ...      ...
# 19995  303.1632  60.2862
# 19996  301.3995  63.7061
# 19997  301.3993  63.7056
# 19998  300.4913  65.8903
# 19999  300.3917  70.4546
#
# [20000 rows x 2 columns]

# %%
df2 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df2.csv',header=0,delimiter=',')
df3 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df3.csv',header=0,delimiter=',')
df4 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df4.csv',header=0,delimiter=',')
df5 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df5.csv',header=0,delimiter=',')
df6 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df6.csv',header=0,delimiter=',')
df7 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df7.csv',header=0,delimiter=',')
df8 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df8.csv',header=0,delimiter=',')

# %%
plt.scatter(df1["col1"], df1["col2"], s=0.5, color = "blue")

# %%
plt.scatter(df2["col1"], df2["col2"], s=0.5, color = "red")

# %%
plt.scatter(df3["col1"], df3["col2"], s=0.5, color = "purple")

# %%
plt.scatter(df4["col1"], df4["col2"], s=0.5, color = "pink")

# %%
plt.scatter(df5["col1"], df5["col2"], s=0.5, color = "orange")

# %%
plt.scatter(df6["col1"], df6["col2"], s=0.5, color = "green")

# %%
plt.scatter(df7["col1"], df7["col2"], s=0.5, color = "yellow")

# %%
plt.scatter(df8["col1"], df8["col2"], s=0.5, color = "gray")

# %%
import astropy
from astropy.coordinates import SkyCoord

c_old = SkyCoord([df1['col1'].to_numpy()], [df1['col2'].to_numpy()], frame='icrs',unit='degree') #replace df1 if your variable names are different 
c_new = c_old.galactic
for count in range(len(c_new[0])):
        df1_new_col1 = c_new[0].l.degree
        df1_new_col2 = c_new[0].b.degree
new_data = {'col1':df1_new_col1,'col2':df1_new_col2}
df1_new = pd.DataFrame(new_data)

# %%
df1_new

# %%
plt.scatter(df1_new['col1'],df1_new['col2'], s = 0.1, color = "red")

# %%
import astropy
from astropy.coordinates import SkyCoord

c_old = SkyCoord([df2['col1'].to_numpy()], [df2['col2'].to_numpy()], frame='icrs',unit='degree') #replace df1 if your variable names are different 
c_new = c_old.galactic
for count in range(len(c_new[0])):
        df2_new_col1 = c_new[0].l.degree
        df2_new_col2 = c_new[0].b.degree
new_data = {'col1':df2_new_col1,'col2':df2_new_col2}
df2_new = pd.DataFrame(new_data)

# %%
plt.scatter(df2_new['col1'],df2_new['col2'], s = 0.1, color = "blue")

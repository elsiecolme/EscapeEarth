# %% [markdown]
# <a href="https://colab.research.google.com/github/liscolme/EscapeEarth/blob/main/Interns/Elise/FoldFunction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## mount google drive to access files

from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
#standard imports
# !pip install lightkurve==1.9.0 #b/c non-standard library
import lightkurve as lk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

## import our custom modules

import sys
sys.path.append('/content/gdrive/My Drive/EscapeEarthData/')
import OpenAndPlot as op

# %%
ticid = 26489741
sector = 15
target = [ticid, sector]

star_1 = op.OpenAndPlot(target)
lc = star_1.open_lc('clean')
lc
# Out:
# TessLightCurve(TICID: None)

# %%
folded = lc.fold(period=2.465579)

# %matplotlib inline
lc.plot()

# %%
# %matplotlib inline
folded.plot()

# %%
def folded(tic,sector,pd):
  target = [tic, sector]
  star_1 = op.OpenAndPlot(target)
  lc = star_1.open_lc('clean')
  folded = lc.fold(period = pd)

  return folded.scatter()

# %%
folded(26489741,15,2.465579)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-83a41d3cb921> in <module>()
# ----> 1 dc= allstats_aftercut[["TIC","Sector"]]
#       2 dc
#
# NameError: name 'allstats_aftercut' is not defined
